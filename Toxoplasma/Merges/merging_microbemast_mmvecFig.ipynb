# %%
mmvec<-read.csv("C:/Users/caitl/OneDrive/Desktop/Toxoplasma/mmvec data/mmvec figures/data_merge_dropnomatch_CN_NAdrop_RFdrop_nofamily5_abfamily_SIC50.csv")
head(mmvec)
# Out:
#   features      A          B           C          D          E
# 1 X160.133_0.28  1.3011787 -3.12916626 -2.2888834 -2.1919065  2.472249
# 2 X162.112_0.26 -1.3761057 -1.40681081 -2.1401495 -0.3797741 -2.058991
# 3 X175.118_0.26  0.1017403 -0.91858653  0.6062755 -2.8092738  2.510896
# 4 X192.065_2.15 -1.0450399  0.00965867  1.1479128 -2.4153869  1.107805
# 5 X205.096_3.47  0.7186971 -0.37887720 -0.4425379  0.0619328  1.309384
# 6 X220.117_0.53 -1.5137450 -0.90474888 -1.1759124 -0.7380068 -2.087628
#   F          G          H           I          ... CF_MFramework_score
# 1  0.9908099  0.3236326  1.63174804 -0.3532461 ... 0.06666667
# 2 -0.5260149 -0.2724257 -0.05635216  0.3001170 ... 0.06666667
# 3 -0.1755588  1.3028469 -0.18574401 -0.9982251 ... 0.33333333
# 4 -0.7605540  1.6974055 -0.85820925 -0.6452233 ... 0.15476191
# 5  1.7794708  3.0090564  2.53082371  2.3675888 ... 0.37500000
# 6 -1.6892520 -2.1697768 -1.88245957 -1.6237075 ... 0.57142857
# ...

# %%
microbemast<- read.csv("C:/Users/caitl/OneDrive/Desktop/Toxoplasma/merged_supplemental_tables/merged_fch/merged_SIC50_foldchange.csv")
head(microbemast)
# Out:
#   features       Cluster.Index M.Z      RT
# 1 X100.51_5.64    246           100.510 5.64
# 2 X1011.561_2.39 6173          1011.561 2.39
# 3 X112.966_5.65   173           112.966 5.65
# 4 X136.075_3.25  5795           136.075 3.25
# 5 X151.075_2.46  6501           151.075 2.46
# 6 X151.625_0.25  2528           151.625 0.25
#   Annotation                                              Cosine.Score
# 1 NA                                                            NA
# 2 taurocholic acid                                        0.839193
# 3 NA                                                            NA
# 4 NA                                                            NA
# 5 Spectral Match to Palmitic acid ethyl ester from NIST14 0.885340
# 6 N-methylcytisine                                        0.782021
#   No..of.Shared.Peaks Mass.Diff..to.Library.Reference ppm.error Analog. ...
# 1 NA                        NA                              NA  No      ...
# ...

# %%
merged_mmvec_microbemast<-merge(mmvec, microbemast, by="features", all=FALSE)
dim(microbemast)
dim(mmvec)
dim(merged_mmvec_microbemast)
head(merged_mmvec_microbemast)
# Out:
# [1] 116 709
# [1] 24 44
# [1]  20 752
#   features      A          B           C          D          E
# 1 X160.133_0.28  1.3011787 -3.12916626 -2.2888834 -2.1919065  2.472249
# 2 X162.112_0.26 -1.3761057 -1.40681081 -2.1401495 -0.3797741 -2.058991
# 3 X175.118_0.26  0.1017403 -0.91858653  0.6062755 -2.8092738  2.510896
# 4 X192.065_2.15 -1.0450399  0.00965867  1.1479128 -2.4153869  1.107805
# 5 X205.096_3.47  0.7186971 -0.37887720 -0.4425379  0.0619328  1.309384
# 6 X220.117_0.53 -1.5137450 -0.90474888 -1.1759124 -0.7380068 -2.087628
#   F          G          H           I          ... microbeMASST_687
# 1  0.9908099  0.3236326  1.63174804 -0.3532461 ... NA
# 2 -0.5260149 -0.2724257 -0.05635216  0.3001170 ... NA
# 3 -0.1755588  1.3028469 -0.18574401 -0.9982251 ... NA
# 4 -0.7605540  1.6974055 -0.85820925 -0.6452233 ... NA
# 5  1.7794708  3.0090564  2.53082371  2.3675888 ... Enterobacter aerogenes
# 6 -1.6892520 -2.1697768 -1.88245957 -1.6237075 ... NA
#   microbeMASST_688
# 1 NA
# ...

# %%
write.csv(merged_mmvec_microbemast, "merged_microbemast_mmvecFigSIC50.csv", row.names=FALSE)
