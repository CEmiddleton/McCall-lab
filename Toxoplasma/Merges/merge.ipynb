# %%
supp<- read.csv("C:/Users/caitl/OneDrive/Desktop/Toxoplasma/redo/duodenum_50_csv.csv")
fch<- read.csv("C:/Users/caitl/OneDrive/Desktop/Toxoplasma/redo/SI_duodenum_fold_change_50.csv")

head(supp)
head(fch)

merged_data_12 <- merge(supp, fch, by = "features", all = FALSE)

write.csv(merged_data_12, "duodenum_50_merged_fch.csv", row.names= FALSE)
# Out:
#   features      Cluster.Index M.Z     RT
# 1 X421.27_3.19  3616          421.270 3.19
# 2 X530.323_2.86 1679          530.323 2.86
# 3 X318.165_3.48 7910          318.165 3.48
# 4 X766.535_3.72 1030          766.535 3.72
# 5 X392.183_2.15 4208          392.183 2.15
# 6 X478.291_2.79 9499          478.291 2.79
#   Annotation
# 1 NA
# 2 NCGC00380283-01!4-[5-[[4-[5-[acetyl(hydroxy)amino]pentylamino]-4-oxobutanoyl]-hydroxyamino]pentylamino]-4-oxobutanoic acid
# 3 Ile-Trp
# 4 NA
# 5 NA
# 6 NCGC00380283-01!4-[5-[[4-[5-[acetyl(hydroxy)amino]pentylamino]-4-oxobutanoyl]-hydroxyamino]pentylamino]-4-oxobutanoic acid
#   Cosine.Score No..of.Shared.Peaks Mass.Diff..to.Library.Reference ppm.error
# 1       NA     NA                           NA                              NA
# 2 0.729268      9                  52.03620000                     108797.0000
# 3 0.839114      8                   0.01358030                         42.6814
# ...
